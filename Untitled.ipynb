# %%
import pandas as pd,numpy as np

# %%
df=pd.read_csv("https://media-doselect.s3.amazonaws.com/generic/1YZQ77KLVyegqroyJgk5Z7d1/titaniMod2.csv")

# %%
df
# Out:
#       Age Cabin        Date Embarked     Fare  \
# 0    34.5   NaN  1979-10-07        Q   7.8292
# 1    47.0   NaN  1979-10-07        S   7.0000
# 2    62.0   NaN  1979-10-07        Q   9.6875
# 3    27.0   NaN  1979-10-07        S   8.6625
# 4    22.0   NaN  1979-10-07        S  12.2875
# ..    ...   ...         ...      ...      ...
# 831   NaN   NaN         NaN      NaN      NaN
# 832   NaN   NaN         NaN      NaN      NaN
# 833   NaN   NaN         NaN      NaN      NaN
# 834   NaN   NaN         NaN      NaN      NaN
# 835   NaN   NaN         NaN      NaN      NaN
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James    0.0        892.0     3.0
# 1                Wilkes, Mrs. James (Ellen Needs)    0.0        893.0     3.0
# 2                       Myles, Mr. Thomas Francis    0.0        894.0     2.0
# 3                                Wirz, Mr. Albert    0.0        895.0     3.0
# ...

# %%
threshold = len(df.columns) * 0.5
df_cleaned = df.dropna(thresh=threshold)

# %%
df_cleaned
# Out:
#       Age Cabin        Date Embarked      Fare  \
# 0    34.5   NaN  1979-10-07        Q    7.8292
# 1    47.0   NaN  1979-10-07        S    7.0000
# 2    62.0   NaN  1979-10-07        Q    9.6875
# 3    27.0   NaN  1979-10-07        S    8.6625
# 4    22.0   NaN  1979-10-07        S   12.2875
# ..    ...   ...         ...      ...       ...
# 413   NaN   NaN  1979-10-07        S    8.0500
# 414  39.0  C105  1979-10-07        C  108.9000
# 415  38.5   NaN  1979-10-07        S    7.2500
# 416   NaN   NaN  1979-10-07        S    8.0500
# 417   NaN   NaN  1979-10-07        C   22.3583
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James    0.0        892.0     3.0
# 1                Wilkes, Mrs. James (Ellen Needs)    0.0        893.0     3.0
# 2                       Myles, Mr. Thomas Francis    0.0        894.0     2.0
# 3                                Wirz, Mr. Albert    0.0        895.0     3.0
# ...

# %%
df_cleaned.loc[:,'Date']=df['Date'].apply(lambda x: str(x).replace('-',''))

# %%
df_cleaned = df_cleaned.round(2)

# %%
df_cleaned
# Out:
#       Age Cabin      Date Embarked    Fare  \
# 0    34.5   NaN  19791007        Q    7.83
# 1    47.0   NaN  19791007        S    7.00
# 2    62.0   NaN  19791007        Q    9.69
# 3    27.0   NaN  19791007        S    8.66
# 4    22.0   NaN  19791007        S   12.29
# ..    ...   ...       ...      ...     ...
# 413   NaN   NaN  19791007        S    8.05
# 414  39.0  C105  19791007        C  108.90
# 415  38.5   NaN  19791007        S    7.25
# 416   NaN   NaN  19791007        S    8.05
# 417   NaN   NaN  19791007        C   22.36
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James    0.0        892.0     3.0
# 1                Wilkes, Mrs. James (Ellen Needs)    0.0        893.0     3.0
# 2                       Myles, Mr. Thomas Francis    0.0        894.0     2.0
# 3                                Wirz, Mr. Albert    0.0        895.0     3.0
# ...

# %%
print(df_cleaned.shape[0])

print(df_cleaned.shape[1])

print(df_cleaned['Date'].head(10))

print(df_cleaned.select_dtypes(include=['float']).head(5))
# Out:
# 418
# 13
# 0    19791007
# 1    19791007
# 2    19791007
# 3    19791007
# 4    19791007
# 5    19791007
# 6    19791007
# 7    19791007
# 8    19791007
# 9    19791007
# Name: Date, dtype: object
#     Age   Fare  Parch  PassengerId  Pclass  SibSp
# 0  34.5   7.83    0.0        892.0     3.0    0.0
# 1  47.0   7.00    0.0        893.0     3.0    1.0
# 2  62.0   9.69    0.0        894.0     2.0    0.0
# 3  27.0   8.66    0.0        895.0     3.0    0.0
# 4  22.0  12.29    1.0        896.0     3.0    1.0

# %%
import numpy as np



data = np.arange(n)

mean = np.mean(data)
variance = np.var(data, ddof=0)
std_deviation = np.std(data, ddof=0)
 
mean = round(mean, 2)
variance = round(variance, 2)
std_deviation = round(std_deviation, 2)

print(mean)
print(std_deviation)
print(variance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 import numpy as np
# ----> 5 data = np.arange(n)
#       7 mean = np.mean(data)
#       8 variance = np.var(data, ddof=0)
#
# NameError: name 'n' is not defined

# %%
print(data)
